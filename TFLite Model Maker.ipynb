# %% [markdown]
# Referensi :
# 1. https://codelabs.developers.google.com/tflite-object-detection-android#0
# 2. https://colab.research.google.com/github/googlecodelabs/odml-pathways/blob/main/object-detection/codelab2/python/Train_a_salad_detector_with_TFLite_Model_Maker.ipynb

# %%
# !pip install tflite-model-maker
# !pip install -q pycocotools
# !pip install -q tflite-support
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import os
import glob
import PIL.Image

from tflite_model_maker.config import ExportFormat
from tflite_model_maker import model_spec
from tflite_model_maker import object_detector

import tensorflow as tf
assert tf.__version__.startswith('2')

tf.get_logger().setLevel('ERROR')
from absl import logging
logging.set_verbosity(logging.ERROR)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="BgcjS6Yq3oooOHBNhTDZ")
project = rf.workspace("projectn").project("nutriku")
dataset = project.version(5).download("voc")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.2/123.2 kB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 10.3 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=e3079ae916be3918f4e76e689e532219547056af77a4568c4ce81ae79a3bc24c
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# ...
#   Attempting uninstall: urllib3
# ...

# %%
spec = model_spec.get('efficientdet_lite2')

# %%
train_data = object_detector.DataLoader.from_pascal_voc("/content/Nutriku-5/train", "/content/Nutriku-5/train", ["ayam_geprek", "ayam_goreng", "bakso", "batagor", "cendol", "gorengan", "ikan_goreng", "ketoprak", "klepon", "martabak_manis", "martabak_telur", "mie_ayam", "nasi_goreng", "nasi_kuning", "nasi_putih", "onde-onde", "pempek", "pisang_ijo", "rendang", "roti_bakar", "sate_ayam", "soto_ayam", "sup_ayam", "telur_balado"])

# %%
validation_data = object_detector.DataLoader.from_pascal_voc('/content/Nutriku-5/valid', '/content/Nutriku-5/valid', ["ayam_geprek", "ayam_goreng", "bakso", "batagor", "cendol", "gorengan", "ikan_goreng", "ketoprak", "klepon", "martabak_manis", "martabak_telur", "mie_ayam", "nasi_goreng", "nasi_kuning", "nasi_putih", "onde-onde", "pempek", "pisang_ijo", "rendang", "roti_bakar", "sate_ayam", "soto_ayam", "sup_ayam", "telur_balado"])

# %%
test_data = object_detector.DataLoader.from_pascal_voc('/content/Nutriku-5/test', '/content/Nutriku-5/test', ["ayam_geprek", "ayam_goreng", "bakso", "batagor", "cendol", "gorengan", "ikan_goreng", "ketoprak", "klepon", "martabak_manis", "martabak_telur", "mie_ayam", "nasi_goreng", "nasi_kuning", "nasi_putih", "onde-onde", "pempek", "pisang_ijo", "rendang", "roti_bakar", "sate_ayam", "soto_ayam", "sup_ayam", "telur_balado"])

# %%
model = object_detector.create(train_data, epochs=35, model_spec=spec, batch_size=24, train_whole_model=True, validation_data=validation_data)
# Out:
# Epoch 1/35
# 241/241 [==============================] - 381s 1s/step - det_loss: 1.4977 - cls_loss: 1.1454 - box_loss: 0.0070 - reg_l2_loss: 0.0799 - loss: 1.5776 - learning_rate: 0.0190 - gradient_norm: 1.5372 - val_det_loss: 1.4345 - val_cls_loss: 1.0403 - val_box_loss: 0.0079 - val_reg_l2_loss: 0.0802 - val_loss: 1.5147
# Epoch 2/35
# 241/241 [==============================] - 329s 1s/step - det_loss: 0.9284 - cls_loss: 0.6789 - box_loss: 0.0050 - reg_l2_loss: 0.0808 - loss: 1.0092 - learning_rate: 0.0299 - gradient_norm: 1.8610 - val_det_loss: 1.3311 - val_cls_loss: 1.0029 - val_box_loss: 0.0066 - val_reg_l2_loss: 0.0812 - val_loss: 1.4123
# Epoch 3/35
# 241/241 [==============================] - 327s 1s/step - det_loss: 0.8267 - cls_loss: 0.5962 - box_loss: 0.0046 - reg_l2_loss: 0.0817 - loss: 0.9084 - learning_rate: 0.0296 - gradient_norm: 1.8552 - val_det_loss: 1.1374 - val_cls_loss: 0.8222 - val_box_loss: 0.0063 - val_reg_l2_loss: 0.0822 - val_loss: 1.2196
# Epoch 4/35
# ...

# %%
model.evaluate(test_data)
# Out:
# 5/5 [==============================] - 75s 5s/step
# {'AP': 0.454571,
#  'AP50': 0.7067481,
#  'AP75': 0.50843924,
#  'APs': -1.0,
#  'APm': 0.25223115,
#  'APl': 0.46120244,
#  'ARmax1': 0.42191574,
#  'ARmax10': 0.596748,
#  'ARmax100': 0.6258755,
#  'ARs': -1.0,
#  'ARm': 0.39035088,
#  'ARl': 0.6324493,
#  'AP_/ayam_geprek': 0.40793675,
#  'AP_/ayam_goreng': 0.31282184,
#  'AP_/bakso': 0.39168942,
#  'AP_/batagor': 0.6491978,
#  'AP_/cendol': 0.2053411,
#  'AP_/gorengan': 0.18572715,
#  'AP_/ikan_goreng': 0.23154588,
#  'AP_/ketoprak': 0.26542526,
#  'AP_/klepon': 0.50643885,
#  'AP_/martabak_manis': 0.2651315,
#  'AP_/martabak_telur': 0.4355499,
#  'AP_/mie_ayam': 0.40491396,
#  'AP_/nasi_goreng': 0.34607944,
#  'AP_/nasi_kuning': 0.48240802,
#  'AP_/nasi_putih': 0.5959425,
#  'AP_/onde-onde': 0.71480024,
#  'AP_/pempek': 0.4841997,
#  'AP_/pisang_ijo': 0.5292283,
#  'AP_/rendang': 0.62234324,
#  'AP_/roti_bakar': 0.54920405,
#  'AP_/sate_ayam': 0.69904923,
# ...

# %%
model.export(export_dir='/content/model')

# %%
model.evaluate_tflite('/content/model/model.tflite', test_data)
# Out:
# 273/273 [==============================] - 2843s 10s/step
# {'AP': 0.43357462,
#  'AP50': 0.6806051,
#  'AP75': 0.48587912,
#  'APs': -1.0,
#  'APm': 0.22419265,
#  'APl': 0.4413039,
#  'ARmax1': 0.38516614,
#  'ARmax10': 0.53228265,
#  'ARmax100': 0.54865855,
#  'ARs': -1.0,
#  'ARm': 0.30046785,
#  'ARl': 0.5573358,
#  'AP_/ayam_geprek': 0.36337647,
#  'AP_/ayam_goreng': 0.28421736,
#  'AP_/bakso': 0.32565114,
#  'AP_/batagor': 0.54666126,
#  'AP_/cendol': 0.18325691,
#  'AP_/gorengan': 0.18713532,
#  'AP_/ikan_goreng': 0.17217393,
#  'AP_/ketoprak': 0.19333333,
#  'AP_/klepon': 0.47676405,
#  'AP_/martabak_manis': 0.2555353,
#  'AP_/martabak_telur': 0.43976757,
#  'AP_/mie_ayam': 0.36434278,
#  'AP_/nasi_goreng': 0.32959586,
#  'AP_/nasi_kuning': 0.47776535,
#  'AP_/nasi_putih': 0.5871348,
#  'AP_/onde-onde': 0.7080127,
#  'AP_/pempek': 0.48619023,
#  'AP_/pisang_ijo': 0.51517344,
#  'AP_/rendang': 0.6330033,
#  'AP_/roti_bakar': 0.5460729,
#  'AP_/sate_ayam': 0.68572605,
# ...
